# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/Pasta1.xlsx",)
df1 = pd.read_excel("/content/drive/MyDrive/Pasta2.xlsx",)
df2 = pd.read_excel("/content/drive/MyDrive/Pasta3.xlsx",)

# %%
df
# Out:
#    Data de Abertura Trimestre        Região Estado                 Cidade  \
# 0        2021-07-30        Q3  Centro oeste     DF          Brasília / DF
# 1        2021-07-17        Q3           Sul     RS      Porto Alegre / RS
# 2        2021-07-17        Q3       Sudeste     MG          Contagem / MG
# 3        2021-07-17        Q3           Sul     RS      Porto Alegre / RS
# 4        2021-07-15        Q3      Nordeste     PA             Belém / PA
# 5        2021-07-03        Q3       Sudeste     SP              São Paulo
# 6        2021-07-03        Q3       Sudeste     MG         Belo Horizonte
# 7        2021-07-03        Q3       Sudeste     SP              São Paulo
# 8        2021-06-19        Q2       Sudeste     MG               Ipatinga
# 9        2021-06-05        Q2         Norte     MA             Imperatriz
# 10       2021-06-05        Q2       Sudeste     RJ  Campos dos Goytacazes
# 11       2021-05-25        Q2  Centro oeste     GO    Valparaiso de Goiás
# ...

# %%
df1
# Out:
#    Data de Abertura Trimestre        Região Estado                 Cidade  \
# 0        2021-07-03        Q3  Centro oeste     DF          Brasília / DF
# 1        2021-06-19        Q3           Sul     RS      Porto Alegre / RS
# 2        2021-06-05        Q2       Sudeste     MG                     BH
# 3        2021-06-05        Q2           Sul     RS      Porto Alegre / RS
# 4        2021-07-30        Q2      Nordeste     PA             Belém / PA
# 5        2021-07-17        Q2       Sudeste     SP              São Paulo
# 6        2021-07-17        Q2       Sudeste     MG         Belo Horizonte
# 7        2021-07-17        Q3       Sudeste     SP              São Paulo
# 8        2021-07-15        Q2       Sudeste     MG               Ipatinga
# 9        2021-06-05        Q2         Norte     MA             Imperatriz
# 10       2021-06-05        Q2       Sudeste     RJ  Campos dos Goytacazes
# 11       2021-07-30        Q2  Centro oeste     GO    Valparaiso de Goiás
# ...

# %%
df2
# Out:
#    Data de Abertura Trimestre        Região Estado                 Cidade  \
# 0        2021-07-03        Q3  Centro oeste     DF                    NaN
# 1        2021-06-19        Q3           Sul     RS      Porto Alegre / RS
# 2        2021-06-05        Q2       Sudeste     MG                     BH
# 3        2021-06-05        Q2           Sul     RS      Porto Alegre / RS
# 4        2021-07-30        Q2      Nordeste     PA             Belém / PA
# 5        2021-07-17        Q2       Sudeste     SP              São Paulo
# 6        2021-07-17        Q2       Sudeste     MG         Belo Horizonte
# 7        2021-07-17        Q3       Sudeste     SP              São Paulo
# 8        2021-07-15        Q2       Sudeste     MG               Ipatinga
# 9        2021-06-05        Q2         Norte     MA             Imperatriz
# 10       2021-06-05        Q2       Sudeste     RJ  Campos dos Goytacazes
# 11       2021-07-30        Q2  Centro oeste     GO    Valparaiso de Goiás
# ...

# %%
# Juntando dados de dua planilhas de Mesma Extrutura 
df = pd.concat([df,df1,df2])

# %%
# Verificando As 5 primeiras Linha
df.head()
# Out:
#   Data de Abertura Trimestre        Região Estado             Cidade  \
# 0       2021-07-30        Q3  Centro oeste     DF      Brasília / DF
# 1       2021-07-17        Q3           Sul     RS  Porto Alegre / RS
# 2       2021-07-17        Q3       Sudeste     MG      Contagem / MG
# 3       2021-07-17        Q3           Sul     RS  Porto Alegre / RS
# 4       2021-07-15        Q3      Nordeste     PA         Belém / PA
#
#                       Localização  Área Total (m2)  \
# 0               Brasília Shopping             6.00
# 1  Shopping Iguatemi Porto Alegre           107.53
# 2              Itaupower Shopping           110.00
# 3                Moinhos Shopping           109.50
# 4        Boulevard Shopping Belém            51.00
#
#    Nº de Lojas Acumulado por Tipo  Nº Lojas Acumuladas        Tipo  Status
# 0                              28                   270   QUIOSQUE  Aberto
# 1                              18                   269  LOJA LIFE  Aberto
# ...

# %%
# Verificando As 5 Ultimas Linha
df.tail()
# Out:
#    Data de Abertura Trimestre    Região Estado      Cidade  \
# 19       2021-06-19        Q3   Sudeste     MG    Contagem
# 20       2021-06-05        Q3    Norte      AC  Rio Branco
# 21       2021-04-30        Q3    Norte      PA      Marabá
# 22       2021-04-30        Q2       Sul     RS  Rio Grande
# 23       2021-04-24        Q2  Nordeste     BA    Salvador
#
#                     Localização  Área Total (m2)  \
# 19     Via Café Garden Shopping            80.00
# 20           Via Verde Shopping            90.99
# 21      Partage Shopping Marabá            94.77
# 22  Partage Shopping Rio Grande            77.93
# 23            Shopping Paralela            73.89
#
#     Nº de Lojas Acumulado por Tipo  Nº Lojas Acumuladas        Tipo   Status
# 19                             213                   251  LOJA LIFE  Fechado
# 20                             212                   250       LOJA   Aberto
# 21                             211                   249  LOJA LIFE   Aberto
# ...

# %%
#Verificando tipo de dados
df.dtypes
# Out:
# Data de Abertura                  datetime64[ns]
# Trimestre                                 object
# Região                                    object
# Estado                                    object
# Cidade                                    object
# Localização                               object
# Área Total (m2)                          float64
# Nº de Lojas Acumulado por Tipo             int64
# Nº Lojas Acumuladas                        int64
# Tipo                                      object
# Status                                    object
# dtype: object

# %%
# Alterando tipo de dados da coluna "Nº de Lojas Acumulado por Tipo"
df["Nº de Lojas Acumulado por Tipo"] = df["Nº de Lojas Acumulado por Tipo"].astype("object")

# %%
df.dtypes
# Out:
# Data de Abertura                  datetime64[ns]
# Trimestre                                 object
# Região                                    object
# Estado                                    object
# Cidade                                    object
# Localização                               object
# Área Total (m2)                          float64
# Nº de Lojas Acumulado por Tipo             int64
# Nº Lojas Acumuladas                        int64
# Tipo                                      object
# Status                                    object
# dtype: object

# %%
df.head()
# Out:
#   Data de Abertura Trimestre        Região Estado             Cidade  \
# 0       2021-07-30        Q3  Centro oeste     DF      Brasília / DF
# 1       2021-07-17        Q3           Sul     RS  Porto Alegre / RS
# 2       2021-07-17        Q3       Sudeste     MG      Contagem / MG
# 3       2021-07-17        Q3           Sul     RS  Porto Alegre / RS
# 4       2021-07-15        Q3      Nordeste     PA         Belém / PA
#
#                       Localização  Área Total (m2)  \
# 0               Brasília Shopping             6.00
# 1  Shopping Iguatemi Porto Alegre           107.53
# 2              Itaupower Shopping           110.00
# 3                Moinhos Shopping           109.50
# 4        Boulevard Shopping Belém            51.00
#
#    Nº de Lojas Acumulado por Tipo  Nº Lojas Acumuladas        Tipo  Status
# 0                              28                   270   QUIOSQUE  Aberto
# 1                              18                   269  LOJA LIFE  Aberto
# ...

# %%
# Consulta Linhas Com "dados/valores" Faltantes 
df.isnull().sum() #consulta se possui algum linha faltante se sim, somar a quantidade de e mostra em qual coluna esta
# Out:
# Data de Abertura                  0
# Trimestre                         0
# Região                            1
# Estado                            0
# Cidade                            1
# Localização                       0
# Área Total (m2)                   3
# Nº de Lojas Acumulado por Tipo    0
# Nº Lojas Acumuladas               0
# Tipo                              0
# Status                            1
# dtype: int64

# %%
df["Área Total (m2)"].fillna(df["Área Total (m2)"].mean(), inplace=True)

# %%
df["Área Total (m2)"].mean()
# Out:
# 77.46869565217392

# %%
df.isnull().sum()
# Out:
# Data de Abertura                  0
# Trimestre                         0
# Região                            1
# Estado                            0
# Cidade                            1
# Localização                       0
# Área Total (m2)                   0
# Nº de Lojas Acumulado por Tipo    0
# Nº Lojas Acumuladas               0
# Tipo                              0
# Status                            1
# dtype: int64

# %%
df["Área Total (m2)"].fillna(0, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.dropna(subset=all, inplace=True)

# %%
df.dropna(how="all", inplace=True)

# %%
df = pd.concat([df,df1,df2])

# %%
df.tail(15)
# Out:
#    Data de Abertura Trimestre        Região Estado                 Cidade  \
# 9        2021-06-05        Q2         Norte     MA             Imperatriz
# 10       2021-06-05        Q2       Sudeste     RJ  Campos dos Goytacazes
# 11       2021-07-30        Q2  Centro oeste     GO    Valparaiso de Goiás
# 12       2021-07-17        Q2           NaN     BA   Vitória da Conquista
# 13       2021-07-17        Q2       Sudeste     SP                 Santos
# 14       2021-07-17        Q2       Sudeste     SP             Araraquara
# 15       2021-07-15        Q2       Sudeste     SP                   Itu
# 16       2021-07-03        Q2  Centro oeste     DF               Brasília
# 17       2021-07-03        Q3         Norte     PA            Parauapebas
# 18       2021-07-03        Q3           Sul     PR               Cascavel
# 19       2021-06-19        Q3       Sudeste     MG               Contagem
# 20       2021-06-05        Q3        Norte      AC             Rio Branco
# ...

# %% [markdown]
# ### Criando Nova Coluna

# %%
# Criando Coluna Dentro e Multiplicando Elemento ex: Multiplicando Lojas Acumuladas por Tipo
df["Multiplicação De Lojas Acumulados"] = df["Nº de Lojas Acumulado por Tipo"].mul(df["Nº de Lojas Acumulado por Tipo"])

# %%
df.head()
# Out:
#   Data de Abertura Trimestre        Região Estado             Cidade  \
# 0       2021-07-30        Q3  Centro oeste     DF      Brasília / DF
# 1       2021-07-17        Q3           Sul     RS  Porto Alegre / RS
# 2       2021-07-17        Q3       Sudeste     MG      Contagem / MG
# 3       2021-07-17        Q3           Sul     RS  Porto Alegre / RS
# 4       2021-07-15        Q3      Nordeste     PA         Belém / PA
#
#                       Localização  Área Total (m2)  \
# 0               Brasília Shopping             6.00
# 1  Shopping Iguatemi Porto Alegre           107.53
# 2              Itaupower Shopping           110.00
# 3                Moinhos Shopping           109.50
# 4        Boulevard Shopping Belém            51.00
#
#    Nº de Lojas Acumulado por Tipo  Nº Lojas Acumuladas        Tipo  Status  \
# 0                              28                   270   QUIOSQUE  Aberto
# 1                              18                   269  LOJA LIFE  Aberto
# ...
